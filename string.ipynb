# %%
s = "PYTHON"
print(s[1:4])
# Out:
# YTH

# %%
s = "PROGRAMMING"
print(s[-3:])
# Out:
# ING

# %%
s ="DEVELOPER"
print(s[::2])
# Out:
# DVLPR

# %%
s = "ABCDEFGHIJ"
print(s[1:8:2])
# Out:
# BDFH

# %%
s = "12345"
n = int(s[1:4])
n+=10
print(n)
# Out:
# 244

# %%
s = "0123456789"
print(s[1:-1:3])
# Out:
# 147

# %%
s = "ABCDEFGHIJKLM"
print(s[2:11:3])
# Out:
# CFI

# %%
s = "PROGRAMMING"
a = len(s)//2
print(a)
# Out:
# 5

# %%
s = "DEVELOPER"
print(s[5:3:-1])
print(s[-3:-6:-1])
print(s[-6:-9:-1])
# Out:
# OL
# POL
# EVE

# %%
s ="Doxpro  "
print(s[-4:-7:-1])
# Out:
# rpx

# %%
s ="Doxpro Robotics"
print(s[-10:-13:-1])
# Out:
# orp

# %%
a = int(input("Enter value"))
if  a>=0 :
    print(f"{a} is positive number")
else:
    print(f"{a} is negative number")

print("task is scuccesfully done")
# Out:
# 25 is positive number
# task is scuccesfully done

# %%
a = 20
b =  30 
c = 5
if a>b & a >c :
    print(f"{a} is greater")
elif b>a & b>c :
    print(f"{b} is greater")
else :
    print(f"{c} is greater")
# Out:
# 30 is greater

# %%
num = int(input("Enter a number:"))
if num%2==0 :
    print(f"{num} is Even Number")
else:
    print(f"{num} is Odd Number")
# Out:
# 13 is Odd Number

# %%
str = "DEVELOPER"
str1 = "ELO"
if str[3:6] in str1 :
    print("detected")
else:
    print("Not detected")
# Out:
# detected

# %%
str = input("Enter a String:")
str1 = input("Enter String you have to find:")

if str in str1 :
    print("Dectected")
else:
    print("Not Detected")
# Out:
# Not Detected

# %%
str = input("Enter a Character(single character only):")
if len(str)== 1 :
    if str in 'a' or  'e' or 'i' or  'o' or  'u' :
        print(f"{str} is Vowels")
    else:
        print(f"{str} is Consonant")
else:
    print("INVALID !!You Enter a moer than one character")
# Out:
# INVALID !!You Enter a moer than one character
